# %%
from quantsim import QuantumMachine, ket
from quantsim.gates import *

# %%
with QuantumMachine(num_qubits=1) as qm:
    qm.get_qubit() - H - Rz(180);
    print(qm.get_qubit())
# Out:
# (0.7071067811865475+0j)|0> + (-0.31683589243571414+0.6321511031901031j)|1>

# %%
with QuantumMachine(num_qubits=1) as qm:
    qm.get_qubit() - H - Z;
    print(qm.get_qubit())
# Out:
# (0.7071067811865475+0j)|0> + (-0.7071067811865475+0j)|1>

# %%
ket('-')
# Out:
# (0.7071067811865475+0j)|0> + (-0.7071067811865475+0j)|1>

# %%
with QuantumMachine(num_qubits=2) as qm:
    qm.get_qubit(0) - H;
    qm.get_qubit(0)@qm.get_qubit(1) - CNOT;
# Out:
# 0j|0> + (1+0j)|1>
#
# 0j|0> + (1+0j)|1>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect('equal')

# draw sphere
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax.plot_wireframe(x, y, z, color='r')

# draw a point
ax.scatter([0], [0], [0], color='g', s=100)

plt.show()
